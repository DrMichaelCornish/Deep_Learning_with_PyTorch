# %% [markdown]
# I am only going to briefly read this chapter as I have an LLM book that treats the topic in more detail and with more up-to-date methods.
#
# That being said, that book does not go into word embeddings in great detail, so the follow resource may be helpful to come back to:
#
# https://code.google.com/archive/p/word2vec
