# %% [markdown]
# This format will be covered more extensively in part two. The major difference for now is that our tensor format should follow
#
# Number x Channel X Depth x Height x Width
#
# Where Number is the data index while depth in the case of, say CT scans, is a physical offset in space.

# %%
import imageio.v2 as imageio

dir_path = '../../data/p1ch4/volumetric-dicom/2-LUNG 3.0  B70f-04083/'
vol_arr = imageio.volread(dir_path, 'DICOM')
vol_arr.shape
# Out:
# Reading DICOM (examining files): 1/99 files (1.0%99/99 files (100.0%)
#   Found 1 correct series.
# Reading DICOM (loading data): 99/99  (100.0%)
# (99, 512, 512)

# %%
# to account for the lack of a color channel, we need to use unsqueeze to introduce a dimensional padding for channel

import torch

vol = torch.from_numpy(vol_arr).float()
vol = torch.unsqueeze(vol,0)

vol.shape
# Out:
# torch.Size([1, 99, 512, 512])
